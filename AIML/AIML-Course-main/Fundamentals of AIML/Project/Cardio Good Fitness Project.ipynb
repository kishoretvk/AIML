# %% [markdown]
# # Project Requirement
#
# ### Description
#
# **Objective** - Preliminary Data Analysis. Explore the dataset and practice extracting basic observations about the data. The idea is to get you comfortable working in Python.
#
# You are expected to do the following :
#
# 1. Come up with a customer profile (characteristics of a customer) of the different products
# 2. Perform univariate and multivariate analyses
# 3. Generate a set of insights and recommendations that will help the company in targeting new customers
#
# **Context** - The data is about customers of the treadmill product(s) of a retail store called Cardio Good Fitness. It contains the following variables-
#
# 1. Product - The model no. of the treadmill
# 2. Age -  Age of the customer in no of years
# 3. Gender - Gender of the customer
# 4. Education - Education of the customer in no. of years
# 5. Marital Status - Marital status of the customer
# 6. Usage - Avg. # times the customer wants to use the treadmill every week
# 7. Fitness - Self rated fitness score of the customer (5 - very fit, 1 - very unfit)
# 8. Income - Income of the customer
# 9. Miles- Miles that a customer expects to run
#
# Explore the dataset to identify differences between the customers of each product. You can also explore relationships between the different attributes of the customers. You can approach it from any other line of questioning that you feel could be relevant for the business.

# %% [markdown]
# # Project Solution
#
# ## Descriptive statistics and visualization of data
#
# ### Importing modules used for Data Visualization

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt # using for ploting different graphs to visualize the data
import seaborn as sns
sns.set(color_codes=True) # adds a nice background to the graphs

# %% [markdown]
# ### Load and Prepare data for Visualization

# %%
data = pd.read_csv('CardioGoodFitness.csv') # Read CSV file and load as Data Frame

# %%
data # checking sample data in data frame
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
data.shape # checking shape of data frame. It has 180 rows and 9 columns
# Out:
# (180, 9)

# %%
data.info() # checking data types in data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
data.isna().any() # Checking for any missing values. It has no missing data.
# Out:
# Product          False
# Age              False
# Gender           False
# Education        False
# MaritalStatus    False
# Usage            False
# Fitness          False
# Income           False
# Miles            False
# dtype: bool

# %%
data.describe(include='all') # checking data frame and understanding the data distribution in each columns.
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
data['Product'].unique() # All unique Products
# Out:
# array(['TM195', 'TM498', 'TM798'], dtype=object)

# %%
data['Product'].value_counts() # Checking customers count for each product
# Out:
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64

# %% [markdown]
# #### Analysis of data frame
#
# 1. 3 Products are in data frame.
# 2. Customers ages from 24 to 33 are using more.
# 3. More customers has education between 14-16 years.
# 4. Customers usage more in 3-4 times in a weeks.
# 5. Customers fitness more between 3-4.
# 6. Customers income more between 44058-58668.
# 7. Customers miles more between 66-114.

# %% [markdown]
# ### Analysis of spread and distribution of every feature in the dataset

# %%
# Visualize data for each feature. Comparing data distribution of Products for each feature 
fig, axs = plt.subplots(3, 3, figsize=(15, 15))

sns.histplot(data=data, x="Age", hue="Product", multiple="dodge", shrink=.8, bins=5, kde=True, ax=axs[0, 0])
sns.histplot(data=data, x="Education", hue="Product", multiple="dodge", shrink=.8, bins=5, kde=True, ax=axs[0, 1])
sns.histplot(data=data, x="Income", hue="Product", multiple="dodge", shrink=.8, bins=4, kde=True, ax=axs[0, 2])
sns.histplot(data=data, x="Usage", hue="Product", multiple="dodge", shrink=.8, kde=True, ax=axs[1, 0])
sns.histplot(data=data, x="Fitness", hue="Product", multiple="dodge", shrink=.8, kde=True, ax=axs[1, 1])
sns.histplot(data=data, x="Miles", hue="Product", multiple="dodge", shrink=.8, bins=5, kde=True, ax=axs[1, 2])
sns.histplot(data=data, x="Gender", hue="Product", multiple="dodge", shrink=.8, ax=axs[2, 0])
sns.histplot(data=data, x="MaritalStatus", hue="Product", multiple="dodge", shrink=.8, ax=axs[2, 1])
sns.histplot(data=data, x="Product", shrink=.8, ax=axs[2, 2])

plt.show()

# %% [markdown]
# #### Analysis of each feature
#
# 1. **Age**: <40 Years customers are buying more products than other customers.
# 2. **Education**: <18 years are buying TM195 and TM498. >=16 years customers like TM798.
# 3. **Income**: <=60000 income customers like TM195 and TM498. >=60000 income customers like TM798.
# 4. **Usage**: <=4 times a week are using TM195 and TM498. >=4 times a week are using TM798.
# 5. **Fitness**: <=4 rated fitness score customers are using TM195 and TM498. >=4 rated fitness score customers are using TM798.
# 6. **Miles**: <200 miles customers are using TM195 and TM498. >=100 miles customers are using TM798.
# 7. **Gender**: Male and Female like TM195 more. But Female don't like TM798.
# 8. **MaritalStatus**: Partnered customers using more products than single customers. Partnered and Single both likes TM195.
# 9. **Product**: Customers more likes TM195 than TM498 and than TM798.

# %% [markdown]
# ### Analysis of interaction between features, in the dataset

# %%
sns.heatmap(data.corr(), annot=True) # checking the correlation of the different variables.
# Out:
# <AxesSubplot:>

# %%
# using pairplot to understand the correlation of all the numerical columns. 
sns.set_theme(style="ticks")
sns.pairplot(data=data, hue='Product')

# %% [markdown]
# **Education and Income are correlated variables. Where Usage, Fitness and Miles are correlated variables. Ploting the graphs using Income, Usage and Age as numerical variables.**

# %%
fig, axs = plt.subplots(2,3, figsize=(15, 15))
sns.boxplot(x='Gender', y='Income', hue='Product', data=data, ax=axs[0,0])
sns.boxplot(x='Gender', y='Usage', hue='Product', data=data, ax=axs[0,1])
sns.boxplot(x='Gender', y='Age', hue='Product', data=data, ax=axs[0,2])
sns.boxplot(x='MaritalStatus', y='Income', hue='Product', data=data, ax=axs[1,0])
sns.boxplot(x='MaritalStatus', y='Usage', hue='Product', data=data, ax=axs[1,1])
sns.boxplot(x='MaritalStatus', y='Age', hue='Product', data=data, ax=axs[1,2])
plt.show()

# %% [markdown]
# ### Conclusion and Recommendations
#
# 1. **TM195** Product is popular among all type of customers, it recommend to sell more of this product.
# 2. **TM195** and **TM498** has a same type of customers, more customers are using **TM195**. Recommend remove **TM498** product from market and promote **TM195**.
# 3. Since <40 years age customers are using more, it's recommend to encourage the customers of >40 years age to use the product.
# 4. **TM798** product using for more fit, more usage, more educated, more income and more miles customes. Recommend to promote this product to premium customers.
# 5. Female are using more TM498 than male.
# 6. Partnered are using less TM498.
