# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # using for ploting different graphs to visualize the data
import seaborn as sns
sns.set(color_codes=True) # adds a nice background to the graphs

# %%
odi = pd.read_csv('Dateset_ODI.csv')
book = pd.read_csv('prog_book.csv')

# %%
odi
# Out:
#        Scorecard        Team 1       Team 2        Winner     Margin  \
# 0        ODI # 1     Australia      England     Australia  5 wickets
# 1        ODI # 2       England    Australia       England  6 wickets
# 2        ODI # 3       England    Australia     Australia  5 wickets
# 3        ODI # 4       England    Australia       England  2 wickets
# 4        ODI # 5   New Zealand     Pakistan   New Zealand    22 runs
# ...          ...           ...          ...           ...        ...
# 3927  ODI # 3928         India  New Zealand   New Zealand  6 wickets
# 3928  ODI # 3929  South Africa   Bangladesh  South Africa   200 runs
# 3929  ODI # 3930      Pakistan    Sri Lanka      Pakistan  9 wickets
# 3930  ODI # 3931         India  New Zealand         India  6 wickets
# 3931  ODI # 3932         India  New Zealand         India     6 runs
#
#             Ground    Match Date
# 0        Melbourne   Jan 5, 1971
# 1       Manchester  Aug 24, 1972
# 2           Lord's  Aug 26, 1972
# ...

# %%
book
# Out:
#      Rating Reviews                                         Book_title  \
# 0      4.17   3,829                              The Elements of Style
# 1      4.01   1,406      The Information: A History, a Theory, a Flood
# 2      3.33       0       Responsive Web Design Overview For Beginners
# 3      3.97   1,658  Ghost in the Wires: My Adventures as the World...
# 4      4.06   1,325                                   How Google Works
# ..      ...     ...                                                ...
# 266    3.76       0  3D Game Engine Architecture: Engineering Real-...
# 267    3.94      22                An Introduction to Database Systems
# 268    4.49      36  The Art of Computer Programming, Volumes 1-3 B...
# 269    4.77       4  The Art of Computer Programming, Volumes 1-4a ...
# 270    3.84       5              A Discipline for Software Engineering
#
#                                            Description  Number_Of_Pages  \
# ...

# %%
a = ['x', 'y', 'z']

# %%
b = ['w']

# %%
a.append(b)

# %%
a
# Out:
# ['x', 'y', 'z', ['w']]

# %%
a = ('x', 'y', 'z')

# %%
a[0] = 't'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-b16ce9db5a63> in <module>
# ----> 1 a[0] = 't'
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(a)
# Out:
# ('x', 'y', 'z')

# %%
x = 1
for i in range(1,10,2):
    print(x*i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
 a = np.array([['m', '2'],['n','3']])

# %%
a[0,1]
# Out:
# '2'

# %%
book
# Out:
#      Rating Reviews                                         Book_title  \
# 0      4.17   3,829                              The Elements of Style
# 1      4.01   1,406      The Information: A History, a Theory, a Flood
# 2      3.33       0       Responsive Web Design Overview For Beginners
# 3      3.97   1,658  Ghost in the Wires: My Adventures as the World...
# 4      4.06   1,325                                   How Google Works
# ..      ...     ...                                                ...
# 266    3.76       0  3D Game Engine Architecture: Engineering Real-...
# 267    3.94      22                An Introduction to Database Systems
# 268    4.49      36  The Art of Computer Programming, Volumes 1-3 B...
# 269    4.77       4  The Art of Computer Programming, Volumes 1-4a ...
# 270    3.84       5              A Discipline for Software Engineering
#
#                                            Description  Number_Of_Pages  \
# ...

# %%
book['Type'].value_counts()
# Out:
# Paperback                156
# Hardcover                 95
# Kindle Edition            10
# ebook                      7
# Unknown Binding            2
# Boxed Set - Hardcover      1
# Name: Type, dtype: int64

# %%
book['Rating'].mode()
# Out:
# 0    4.15
# dtype: float64

# %%
book[book['Type'==Paperback]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-9749d5355505> in <module>
# ----> 1 book[book['Type'==Paperback]]
#
# NameError: name 'Paperback' is not defined

# %%
sns.distplot(book['Price'])
# Out:
# /Users/pranabkb/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.countplot(book['Type'])
# Out:
# /Users/pranabkb/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
sns.boxplot(data = book, x ='Rating', y ='Type');

# %%
sns.stripplot(data = book, x = 'Type', y='Rating', jitter=True);

# %%
sns.jointplot(data = book, x= 'Price', y = 'Rating', kind="kde");

# %%
sns.jointplot(data = book, x= 'Price', y = 'Number_Of_Pages');

# %%
book
# Out:
#      Rating Reviews                                         Book_title  \
# 0      4.17   3,829                              The Elements of Style
# 1      4.01   1,406      The Information: A History, a Theory, a Flood
# 2      3.33       0       Responsive Web Design Overview For Beginners
# 3      3.97   1,658  Ghost in the Wires: My Adventures as the World...
# 4      4.06   1,325                                   How Google Works
# ..      ...     ...                                                ...
# 266    3.76       0  3D Game Engine Architecture: Engineering Real-...
# 267    3.94      22                An Introduction to Database Systems
# 268    4.49      36  The Art of Computer Programming, Volumes 1-3 B...
# 269    4.77       4  The Art of Computer Programming, Volumes 1-4a ...
# 270    3.84       5              A Discipline for Software Engineering
#
#                                            Description  Number_Of_Pages  \
# ...

# %%
book.groupby('Type').Price.max()
# Out:
# Type
# Boxed Set - Hardcover    220.385294
# Hardcover                235.650000
# Kindle Edition            51.464706
# Paperback                212.097059
# Unknown Binding           38.297059
# ebook                     83.211765
# Name: Price, dtype: float64

# %%
book.where(book["Type"]=="Paperback")
# Out:
#      Rating Reviews                           Book_title  \
# 0       NaN     NaN                                  NaN
# 1       NaN     NaN                                  NaN
# 2       NaN     NaN                                  NaN
# 3       NaN     NaN                                  NaN
# 4       NaN     NaN                                  NaN
# ..      ...     ...                                  ...
# 266     NaN     NaN                                  NaN
# 267    3.94      22  An Introduction to Database Systems
# 268     NaN     NaN                                  NaN
# 269     NaN     NaN                                  NaN
# 270     NaN     NaN                                  NaN
#
#                                            Description  Number_Of_Pages  \
# 0                                                  NaN              NaN
# 1                                                  NaN              NaN
# ...

# %%
book.loc[book["Type"]=="Paperback"].sort_values(by='Rating', ascending=False)
# Out:
#      Rating Reviews                                         Book_title  \
# 131    4.72     362  Designing Data-Intensive Applications: The Big...
# 194    4.67      78  Fluent Python: Clear, Concise, and Effective P...
# 114    4.67       1  Build Web Applications with Java: Learn every ...
# 9      4.62       0  ZX Spectrum Games Code Club: Twenty fun games ...
# 198    4.58      58                   CLR via C# (Developer Reference)
# ..      ...     ...                                                ...
# 86     3.22       2                                   Beginning Java 2
# 24     3.20       0                      Game Programming Golden Rules
# 187    3.00       0  Lambda-Calculus, Combinators and Functional Pr...
# 177    3.00       0  Advanced Game Programming: A Gamedev.Net Colle...
# 182    3.00       0  Cross-Platform Game Programming (Game Developm...
#
#                                            Description  Number_Of_Pages  \
# ...
